# %% [markdown]
# # Import Libraries
# ### For web scrapping

# %% [markdown]
# the data will be taken from imdb website: https://www.imdb.com/search/title/?country_of_origin=id&sort=release_date,asc&start=1

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from requests import get
from bs4 import BeautifulSoup as Soup
from bs4 import NavigableString, Tag

# %% [markdown]
# ## Get the site necessity

# %%
url = get("https://www.imdb.com/search/title/?country_of_origin=id&sort=release_date,desc&start=51&ref_=adv_nxt")

# %%
request = url.text

# %% [markdown]
# ### Parse the whole site

# %%
total_soup = Soup(request,'html.parser')

# %% [markdown]
# ### Get the part related to the Movie profiles

# %%
total_movies = total_soup.findAll('div',{'class':'lister-item mode-advanced'})

# %% [markdown]
# ### Find the number of possible pages that wee need to get all movies

# %% [markdown]
# #### In this case, it is 69, as the movie list has 3490 entry, and each page contains 50 movies.

# %%
total_movie = total_soup.find('div', {'class':'desc'}).find('span').text
page_count = total_movie[total_movie.find('of ')+3:total_movie.find(' titles')].replace(',','')
pages = int(float(page_count)/50)
print(pages)
# Out:
# 69

# %% [markdown]
# ## Script below is to get List of Movies

# %%
Title = []
Year = []
Synopsis = []
Runtime = []
Genre = []
Rating = []
Actors =[]
Director = []
Votes = []

for pag in range(pages):
    page = (pag*50)+1
    url = "https://www.imdb.com/search/title/?country_of_origin=id&sort=release_date,desc&start={}&ref_=adv_nxt".format(page)
    request = get(url).text
    soup_data = Soup(request,'html.parser')
    movies = soup_data.findAll('div',{'class':'lister-item mode-advanced'})
    for mov in movies:
        #TITLE
        Title.append(mov.h3.a.text)

        #YEAR
        try:
            Year.append(mov.find('span',{"class": "lister-item-year text-muted unbold"}).text[1:5])
        except TypeError:
            Year.append(np.nan)
        except AttributeError:
            Year.append(np.nan)
            
        #SYNOPSIS
        try:
            Synopsis.append(mov.find_all('p',{"class": "text-muted"})[1].text[5:])
        except TypeError:
            Synopsis.append(np.nan)
        except AttributeError:
            Synopsis.append(np.nan)

        #RUNTIME
        try:
            Runtime.append(mov.find('span',{"class": "runtime"}).text[:-4])
        except AttributeError:
            Runtime.append(np.nan)
        except TypeError:
            Runtime.append(np.nan)

        #GENRE
        try:
            Genre.append(mov.find('span',{"class": "genre"}).text[1:-12])
        except AttributeError:
            Genre.append(np.nan)
            
        #RATING
        try:
            Rating.append(mov.find('div',{"class":"inline-block ratings-imdb-rating"})["data-value"])
        except AttributeError:
            Rating.append(np.nan)
        except TypeError:
            Rating.append(np.nan)

        #VOTES
        try:
            Votes.append(mov.find('span', {"name": "nv"}).text)
        except AttributeError:
            Votes.append(np.nan)
        except TypeError:
            Votes.append(np.nan)

        #ACTORS
        Actors.append([a.text for a in mov.find('p',class_='').find_all('a')[1:]])

        #DIRECTOR
        try:
            Director.append(mov.find('p',class_='').find_all('a')[0].text)
        except AttributeError:
            Director.append(np.nan)
        except IndexError:
            Director.append(np.nan)
#         print(i)

# %%
list=[Title, Year, Synopsis, Runtime, Genre, Rating, Votes, Director, Actors]
df = pd.DataFrame(list).T
df.columns = ["Title", "Year", "Synopses", "Runtime", "Genre", "Rating", "Votes", "Director", "Actors"]
df.head(200)
# Out:
#                                             Title  Year  \
# 0                                       Lingering  Vide
# 1                                     The Teacher   II)
# 2                                   Setan Munafik
# 3                            Esok Yang Lebih Baik
# 4                               Ghost in the Cell
# ..                                            ...   ...
# 195  Payal Dev Feat. Radhika Bangia: Saara India!  2020
# 196                             The Mother's Land  II)
# 197                             The Mother's Land  I) (
# 198                                       Ruwatan  2020
# 199                          Sementara, Selamanya  2020
#
#                                               Synopses Runtime  \
# 0                                             a Plot\n     NaN
# 1                                             a Plot\n     NaN
# 2    Group of Bunch of youngster who like a shopist...     NaN
# 3                                             a Plot\n     NaN
# 4                                             a Plot\n     NaN
# ..                                                 ...     ...
# 195                                           a Plot\n       3
# 196                                           a Plot\n     NaN
# 197  A tale of man who tries to captivate the mothe...     NaN
# 198  Accompanying her blind mother undergo alternat...      15
# 199  Saka and Zara, a husband and wife, who decided...      56
#
#                          Genre Rating Votes        Director  \
# 0                      Mystery    NaN   NaN   Dewi Nurfitri
# 1                       Comedy    NaN   NaN  Estelle Linden
# 2    Horror, Mystery, Thriller    NaN   NaN     Yosua Rocky
# 3         Action, Crime, Drama    NaN   NaN  Baf Sjamsuddin
# 4                          NaN    NaN   NaN      Joko Anwar
# ..                         ...    ...   ...             ...
# 195               Short, Music    NaN   NaN   Mudassar Khan
# 196             Short, Fantasy    NaN   NaN  Kevin Rahardjo
# 197             Short, Fantasy    NaN   NaN  Kevin Rahardjo
# 198               Short, Drama    NaN   NaN  Ernest Lesmana
# 199                      Drama    8.7    10   Reza Rahadian
#
#                                                 Actors
# 0    [Stephen J. Pena, Ryoma Ishizuka, Erin Evans-W...
# 1                 [Estelle Linden, Yova Gracia, Yuven]
# 2    [Majed Salleh, Nabil Ahmad, Jalaluddin Hassan,...
# 3    [Daniel Adnan, Yusof B. Mohd Kassim, Revaldo, ...
# 4                                                   []
# ..                                                 ...
# 195                        [Radhika Bangia, Payal Dev]
# 196                   [Mikael Farady, Sifra Magdalena]
# 197                   [Mikael Farady, Sifra Magdalena]
# 198  [Vonny Anggraini, Johannes de Britto, Anne Yas...
# 199       [Laura Basuki, Ruth Marini, Christine Hakim]
#
# [200 rows x 9 columns]

# %%
df[df["Director"] == "Joko Anwar"].sort_values(by="Year", ascending = False)
# Out:
#                   Title  Year  \
# 1038              Jenny  III)
# 970         Don't Blink  II)
# 323          Impetigore  2019
# 357             Gundala  2019
# 830      Satan's Slaves  2017
# 842         Jalanin Aja  2017
# 1237  A Copy of My Mind  2015
# 1636       Durable Love  2012
# 1664      Grave Torture  2012
# 1710             Ritual  2012
# 2101    Pintu Terlarang  2009
# 2277          Dead Time  2007
# 2361         Janji Joni  2005
# 2383        Ajeng Ajeng  2004
# 2399      Joni Be Brave  2003
